# %%
print("🚀 AI Career Mentor")

print("Choose Career Goal")
print("1. AI Engineer")
print("2. Data Scientist")
print("3. Python Developer")

choice = input("Enter choice: ")
# Out:
# 🚀 AI Career Mentor
# Choose Career Goal
# 1. AI Engineer
# 2. Data Scientist
# 3. Python Developer
# Enter choice: 3

# %%
if choice == "1":

    skills = [
        "Python",
        "NumPy",
        "Pandas",
        "Machine Learning",
        "Deep Learning"
    ]

elif choice == "2":

    skills = [
        "Python",
        "Statistics",
        "Pandas",
        "Data Visualization",
        "Machine Learning"
    ]

else:

    skills = [
        "Python",
        "Functions",
        "OOP",
        "APIs",
        "GitHub"
    ]

# %%
print("\n📚 Recommended Skills\n")

for skill in skills:
    print("-", skill)
# Out:
# 📚 Recommended Skills
#
# - Python
# - Functions
# - OOP
# - APIs
# - GitHub

# %%
print("\n🚀 Suggested Projects\n")

if choice == "1":

    print("- Student Score Predictor")
    print("- AI Study Planner")
    print("- AI Interview Trainer")

elif choice == "2":

    print("- Data Analysis Dashboard")
    print("- Sales Prediction Model")
    print("- Recommendation System")

else:

    print("- Calculator App")
    print("- Weather App")
    print("- Expense Tracker")
# Out:
# 🚀 Suggested Projects
#
# - Calculator App
# - Weather App
# - Expense Tracker

# %%
print("\n🎯 Career Advice")

print(
    "Build projects consistently and document your learning journey on GitHub and LinkedIn."
)
# Out:
# 🎯 Career Advice
# Build projects consistently and document your learning journey on GitHub and LinkedIn.
